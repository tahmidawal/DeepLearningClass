# %% [markdown]
# <a href="https://colab.research.google.com/github/tahmidawal/DeepLearningClass/blob/main/Feb9_Assessment_1_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget 'https://media.istockphoto.com/id/1163188578/hu/fot%C3%B3/parlament-budapesten.jpg?s=1024x1024&w=is&k=20&c=MRifpyqwa5naC0OykR_EUUnwpaRIcdsvZwiCYCPFXjk=' -o ait.jpg

# %%
from IPython.display import Image
Image(filename='ait.jpeg')

# %%
from PIL import Image

# Open the image
img = Image.open("ait.jpeg")

# Get the size of the image
width, height = img.size

# Calculate the coordinates of the top-right 30x30 rectangle
x1 = width - 30
y1 = 0
x2 = width
y2 = 30

# Get the region of the image corresponding to the top-right 30x30 rectangle
region = img.crop((x1, y1, x2, y2))

# Fill the region with black
black = Image.new("RGB", region.size, (0, 0, 0))
img.paste(black, (x1, y1, x2, y2))

# Save the modified image
img.save("modified_image.jpeg")

# %%
from IPython.display import Image
Image(filename='modified_image.jpeg')
